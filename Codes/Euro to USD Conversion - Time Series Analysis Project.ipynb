# %% [markdown]
# # Euro to USD Conversion - Time Series Analysis Project

# %% [markdown]
# ***
# _**Importing the required libraries & packages**_

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import statsmodels.api as sm
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA
from pmdarima import auto_arima
from pandas.plotting import autocorrelation_plot
from math import sqrt
from sklearn.metrics import r2_score, mean_absolute_error, mean_absolute_percentage_error, mean_squared_error
import pickle
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# _**Changing The Default Working Directory Path & Reading the Dataset using Pandas Command and displaying first five records of the dataset**_

# %%
os.chdir('C:\\Users\\Shridhar\\Desktop\\Project')
df = pd.read_csv('BOE-XUDLERD.csv')
df.head()
# Out:
#          Date   Value
# 0  2017-11-09  0.8603
# 1  2017-11-08  0.8631
# 2  2017-11-07  0.8639
# 3  2017-11-06  0.8631
# 4  2017-11-03  0.8608

# %% [markdown]
# ## Exploratory Data Analysis(EDA)

# %% [markdown]
# _**Getting the shape of the dataset**_

# %%
df.shape
# Out:
# (10837, 2)

# %% [markdown]
# _**Checking for the null values in the dataset**_

# %%
df.isna().sum()
# Out:
# Date     0
# Value    0
# dtype: int64

# %% [markdown]
# _**Checkiong for the duplicate values in the dataset**_

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# _**Checking the data type of the columns in the dataset**_

# %%
df.dtypes
# Out:
# Date      object
# Value    float64
# dtype: object

# %% [markdown]
# _**Getting the summary of various descriptive statistics for the numeric column in the dataset**_

# %%
df.describe()
# Out:
#               Value
# count  10837.000000
# mean       0.864988
# std        0.153289
# min        0.626000
# 25%        0.759800
# 50%        0.826300
# 75%        0.920300
# max        1.551900

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# _**Changing the data type of `Date` column as <span style="color:red">DateTime</span> using pandas command**_

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.dtypes
# Out:
# Date     datetime64[ns]
# Value           float64
# dtype: object

# %% [markdown]
# _**Changing the `Date` column as the index column of the dataset and also displaying the first five records of the dataset**_

# %%
df = df.set_index('Date')
df.head()
# Out:
#              Value
# Date
# 2017-11-09  0.8603
# 2017-11-08  0.8631
# 2017-11-07  0.8639
# 2017-11-06  0.8631
# 2017-11-03  0.8608

# %% [markdown]
# ## Data Processing & Visualization

# %% [markdown]
# _**Plotting the line graph to show the data trend in the dataset and saving the graph as PNG file**_

# %%
df.plot(figsize = (10,5))
plt.title('Foreign Exchane Rate - Euro to USD')
plt.savefig('Foreign Exchane Rate - Euro to USD.png')
plt.show()

# %% [markdown]
# _**Resampling the dataset to weekly frequency since the given data has more number of observations that takes longer time to fit or predict the model. And along with that showing number of observations after resampling and displaying the first five records of the resampled dataset**_

# %%
df_week = df.resample('W').mean()
print('Counts of the Weekly DataFrame : ',df_week.shape[0])
df_week.head()
# Out:
# Counts of the Weekly DataFrame :  2237
#               Value
# Date
# 1975-01-05  0.76090
# 1975-01-12  0.75346
# 1975-01-19  0.75546
# 1975-01-26  0.74388
# 1975-02-02  0.73902

# %% [markdown]
# _**Plotting the line graph to show the data trend in the weekly resampled dataset and saving the graph as PNG file**_

# %%
df_week.plot(figsize = (10,5))
plt.title('Foreign Exchane Rate(Weekly) - Euro to USD')
plt.savefig('Foreign Exchane Rate(Weekly) - Euro to USD.png')
plt.show()

# %% [markdown]
# _**Resampling the dataset to monthly frequency since the given data has more number of observations that takes longer time to fit or predict the model. And along with that showing number of observations after resampling and displaying the first five records of the resampled dataset**_

# %%
df_month = df.resample('M').mean()
print('Counts of the Monthly DataFrame : ',df_month.shape[0])
df_month.head()
# Out:
# Counts of the Monthly DataFrame :  515
#                Value
# Date
# 1975-01-31  0.749132
# 1975-02-28  0.737910
# 1975-03-31  0.730337
# 1975-04-30  0.741623
# 1975-05-31  0.731286

# %% [markdown]
# _**Plotting the line graph to show the data trend in the monthly resampled dataset and saving the graph as PNG file**_

# %%
df_month.plot(figsize = (10,5))
plt.title('Foreign Exchane Rate(Monthly) - Euro to USD')
plt.savefig('Foreign Exchane Rate(Monthly) - Euro to USD.png')
plt.show()

# %% [markdown]
# _**Resampling the dataset to Yearly frequency since the given data has more number of observations that takes longer time to fit or predict the model. And along with that showing number of observations after resampling and displaying the first five records of the resampled dataset**_

# %%
df_year = df.resample('Y').mean()
print('Counts of the Yearly DataFrame : ',df_year.shape[0])
df_year.head()
# Out:
# Counts of the Yearly DataFrame :  43
#                Value
# Date
# 1975-12-31  0.766268
# 1976-12-31  0.837672
# 1977-12-31  0.823871
# 1978-12-31  0.747492
# 1979-12-31  0.697025

# %% [markdown]
# _**Plotting the line graph to show the data trend in the Yearly resampled dataset and saving the graph as PNG file**_

# %%
df_year.plot(figsize = (10,5))
plt.title('Foreign Exchane Rate(Yearly) - Euro to USD')
plt.savefig('Foreign Exchane Rate(Yearly) - Euro to USD.png')
plt.show()

# %% [markdown]
# _**Plotting the scatter plot to show the data trend in the weekly resampled dataset and saving the graph as PNG file. And by observing all the above resampled graph, Weekly resampled data has more clear peaks and perks among all resample data**_

# %%
plt.rcParams['figure.figsize'] = (15,7)
sns.scatterplot(x = df_week.index, y = df_week.Value,color = 'black')
plt.title('Foreign Exchane Rate(Weekly) - Euro to USD[Scatter Plot]')
plt.savefig('Foreign Exchane Rate(Weekly) - Euro to USD[Scatter Plot].png')
plt.show()

# %% [markdown]
# _**Plotting the bar graph using seaborn to show the data spread in the resampled weekly data and saving the graph as PNG file**_

# %%
sns.barplot(data = df_week, x = df_week.index, y = df_week.Value)
plt.title('Data Spread of Foreign Exchange Rate through Bar Plot')
plt.savefig('Data Spread of Foreign Exchange Rate through Bar Plot.png')
plt.show()

# %% [markdown]
# _**Plotting the dist plot using Seaborn to show the data distribution in the resampled weekly dataset and saving the graph as PNG file**_

# %%
sns.distplot(df_week)
plt.title('Distrubution of Data in Foreign Exchange Rate - Euro to USD')
plt.savefig('Distrubution of Data in Foreign Exchange Rate - Euro to USD.png')
plt.show()

# %% [markdown]
# _**Plotting the histogram and KDE line graph to show the distribution of data in the resampled weekly dataset and saving the graph as PNG file**_

# %%
fig, (ax1, ax2) = plt.subplots(nrows = 2, ncols = 1, sharex = False, sharey = False, figsize = (10,5))
df_week.hist(ax = ax1)
df_week.plot(kind = 'kde', ax = ax2)
plt.title('Data Distribution of Foreign Exchange Rate')
plt.savefig('Data Distribution of Foreign Exchange Rate.png')
plt.show()

# %% [markdown]
# _**Plotting the graph with "Seasonal Decompose" function to show the Data Description, Trend, Seasonal, Residuals and saving the graph as PNG file**_

# %%
plt.rcParams['figure.figsize'] = (10,5)
decomposition = seasonal_decompose(df_week, period = 52, model = 'additive')
decomposition.plot()
plt.savefig('Trend, Seasonal, Residual Graph.png')
plt.show()

# %% [markdown]
# _**Plotting the graphs with Auto-Correlation and Partial Auto-Correlation of the data from the resampled weekly dataset and saving the graphs as PNG file**_

# %%
fig, (ax1, ax2) = plt.subplots(nrows = 2, ncols = 1, sharex = False, sharey = False, figsize = (10,5))
ax1 = plot_acf(df_week, lags = 5, ax = ax1)
ax2 = plot_pacf(df_week, lags = 5, ax = ax2)
plt.subplots_adjust(hspace = 0.5)
plt.savefig('ACF & PACF.png')
plt.show()

# %% [markdown]
# ## Data Transformation

# %% [markdown]
# _**The `adf_check()` function performs an Augmented Dickey-Fuller test on a time series. The test is used to determine whether a time series is stationary or not. If the p-value of the test is less than or equal to 0.05, then there is strong evidence against the null hypothesis, and the series is considered to be stationary. Otherwise, the series is considered to be non-stationary. The function takes a time series as input and returns the results of the test. The results are printed to the console, along with a message indicating whether the series is stationary or not.**_

# %%
def adf_check (time_series):
    result = adfuller (time_series)
    print ('Augmented Dickey Fuller Test :')
    labels = ['ADF Test Statistics', 'P Value', 'Number of Lags Used','Number of Observations']
    for value, label in zip(result, labels):
        print (label +' : '+ str (value))
    if result [1] <= 0.05:
        print ('Strong evidence against the null hypothesis, hence REJECT null hypothesis and the series is Stationary ')
    else:
        print ('Weak evidence against the null hypothesis, hence ACCEPT null hypothesis and the series is Not Stationary ')

# %% [markdown]
# _**Performing the Augmented Dickey-Fuller test on the original data in the resampled weekly dataset to find whether the time series is stationary or not**_

# %%
adf_check(df_week)
# Out:
# Augmented Dickey Fuller Test :
# ADF Test Statistics : -2.07634059993305
# P Value : 0.25413395509264947
# Number of Lags Used : 2
# Number of Observations : 2234
# Weak evidence against the null hypothesis, hence ACCEPT null hypothesis and the series is Not Stationary

# %% [markdown]
# _**Since the Time Series is Not Stationary, the resampled weekly dataset is transformed as a new DataFrame with First Difference to make it as a Stationary Series. Along with that showing the number of observations in the new DataFrame and displaying the first five records of the new DataFrame**_

# %%
df1_week = df_week.diff().dropna()
print('Counts of the Weekly First Difference DataFrame  : ',df1_week.shape[0])
df1_week.head()
# Out:
# Counts of the Weekly First Difference DataFrame  :  2236
#               Value
# Date
# 1975-01-12 -0.00744
# 1975-01-19  0.00200
# 1975-01-26 -0.01158
# 1975-02-02 -0.00486
# 1975-02-09  0.01004

# %% [markdown]
# _**Performing again the Augmented Dickey-Fuller test on the new transformed data from the resampled weekly dataset to find whether the time series is stationary or not**_

# %%
adf_check(df1_week)
# Out:
# Augmented Dickey Fuller Test :
# ADF Test Statistics : -30.12898660128547
# P Value : 0.0
# Number of Lags Used : 1
# Number of Observations : 2234
# Strong evidence against the null hypothesis, hence REJECT null hypothesis and the series is Stationary

# %% [markdown]
# _**Plotting the line graph to show the data trend in the transformed data from the resampled weekly dataset and saving the graph as PNG file**_

# %%
df1_week.plot(figsize = (10,5))
plt.title('Foreign Exchane Rate(Weekly First Difference) - Euro to USD')
plt.savefig('Foreign Exchane Rate(Weekly First Difference) - Euro to USD.png')
plt.show()

# %% [markdown]
# _**Plotting the graph with pandas plotting autocorrelation_plot to show the difference between the Stationary Data and Non-Stationary Data and saving it as PNG file**_

# %%
fig, (ax1, ax2) = plt.subplots(nrows = 2, ncols = 1, sharex = False, sharey = False, figsize = (10,5))
ax1 = autocorrelation_plot(df_week, ax = ax1)
ax1.set_title('Non-Stationary Data')
ax2 = autocorrelation_plot(df1_week, ax = ax2)
ax2.set_title('Stationary Data')
plt.subplots_adjust(hspace = 0.5)
plt.savefig('Autocorrelation_plot of Stationary & Non-Stationary.png')
plt.show()

# %% [markdown]
# ## Model Fitting

# %% [markdown]
# _**Getting the p value and q value for the model fitting using `auto_arima` function by passing through some needed parameters, the best model is evaluated by least Akaike Information Criterion[AIC]**_

# %%
model = auto_arima(df_week, m = 52, d = 1, seasonal = False, max_order = 8, test = 'adf', trace = True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-14195.726, Time=2.28 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-14039.528, Time=0.80 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-14196.131, Time=1.20 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-14200.250, Time=1.64 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-14041.486, Time=0.48 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-14199.705, Time=1.44 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=-14199.738, Time=1.60 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=-14197.726, Time=2.05 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=-14202.222, Time=0.64 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=-14201.680, Time=0.81 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=-14201.713, Time=0.85 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=-14198.107, Time=0.60 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=-14199.700, Time=1.01 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 15.407 seconds

# %% [markdown]
# _**Defining the summary of the model fitted with `auto_arima` function, here getting various information such as Akaike Information Criterion[AIC], Bayesian Information Criterion[BIC}, Hannan-Quinn Information Criterion[HQIC], Log Likelihood etc. from which we can evaluate the model**_

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 2237
# Model:               SARIMAX(0, 1, 1)   Log Likelihood                7103.111
# Date:                Thu, 27 Jul 2023   AIC                         -14202.222
# Time:                        12:27:05   BIC                         -14190.797
# Sample:                    01-05-1975   HQIC                        -14198.051
#                          - 11-12-2017
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1          0.2755      0.015     18.107      0.000       0.246       0.305
# sigma2         0.0001   2.03e-06     50.197      0.000    9.79e-05       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               635.74
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.61   Skew:                            -0.19
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.58
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# _**Fitting the model in ARIMA model with the best value got from `auto_arima` model in the resampled weekly data and getting the summary of the fitted model**_

# %%
model = ARIMA(df_week, order = (0,1,1))
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Value   No. Observations:                 2237
# Model:                 ARIMA(0, 1, 1)   Log Likelihood                7103.111
# Date:                Thu, 27 Jul 2023   AIC                         -14202.222
# Time:                        12:27:05   BIC                         -14190.797
# Sample:                    01-05-1975   HQIC                        -14198.051
#                          - 11-12-2017
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1          0.2755      0.015     18.107      0.000       0.246       0.305
# sigma2         0.0001   2.03e-06     50.197      0.000    9.79e-05       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               635.74
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.61   Skew:                            -0.19
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.58
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# _**Plotting the Diagnostic plot for the fitted model to show the best fit of the model and saving it as PNG file**_

# %%
result.plot_diagnostics(figsize = (15,5))
plt.subplots_adjust(hspace = 0.5)
plt.savefig('Diagnostic Plot of Best Model')
plt.show()

# %% [markdown]
# _**Predicting the values using fitted model with whole resampled weekly data**_

# %%
prediction = result.predict(typ = 'levels')

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# _**Evaluating the model with the following metrics such asPercentage of  R2 Score, Mean Squared Error, Root Mean Squared Error, Mean Absolute Error and Mean Absolute Percentage Error for the predicted value and whole data value**_

# %%
print('Evaluation Results for Whole Data : \n')
print(' Percenatge of R2 Score : {0:.2f} %'.format(100*(r2_score(df_week['Value'],prediction))),'\n')
print(' Mean Squared Error : %.6f'%(mean_squared_error(df_week['Value'],prediction)),'\n')
print(' Root Mean Squared Error : ',sqrt(mean_squared_error(df_week['Value'],prediction)),'\n')
print(' Mean Absolute Error : ',mean_absolute_error(df_week['Value'],prediction),'\n')
print(' Mean Absolute Percentage Error : {0:.2f} %'.format(100*mean_absolute_percentage_error(df_week['Value'],prediction)),'\n')
# Out:
# Evaluation Results for Whole Data :
#
#  Percenatge of R2 Score : 98.46 %
#
#  Mean Squared Error : 0.000361
#
#  Root Mean Squared Error :  0.018991872296134884
#
#  Mean Absolute Error :  0.0077965622688231555
#
#  Mean Absolute Percentage Error : 0.89 %

# %% [markdown]
# ## Result

# %% [markdown]
# _**Concating the Resampled weekly dataset, Weekly First Difference DataFrame and the prediction value and naming the columns as `Foreign Exchange Rate(Weekly)`, `Weekly First Difference`, `Predicted Exchange Rate` and exporting the DataFrame to [Comma Seperated Value]csv file. Also displaying the first five records of the exported DataFrame**_

# %%
df_final = pd.concat([df_week, df1_week, prediction],axis = 1)
df_final.columns = ['Foreign Exchange Rate(Weekly)', 'Weekly First Difference', 'Predicted Exchange Rate']
df_final.to_csv('Foreign Exchange Rate with Prediction (Euro to USD).csv')
df_final.head()
# Out:
#             Foreign Exchange Rate(Weekly)  Weekly First Difference  \
# Date
# 1975-01-05                        0.76090                      NaN
# 1975-01-12                        0.75346                 -0.00744
# 1975-01-19                        0.75546                  0.00200
# 1975-01-26                        0.74388                 -0.01158
# 1975-02-02                        0.73902                 -0.00486
#
#             Predicted Exchange Rate
# Date
# 1975-01-05                 0.000000
# 1975-01-12                 0.760900
# 1975-01-19                 0.751555
# 1975-01-26                 0.756530
# 1975-02-02                 0.740396

# %% [markdown]
# ## Model Testing

# %% [markdown]
# _**Splitting the Resampled Weekly Dataset into training data and test data. And displaying the number of observations in both training data nad test data**_

# %%
size = int(len(df_week)*0.80)
train, test = df_week[0:size]['Value'], df_week[size:(len(df_week))]['Value']
print('Counts of the Train Data : ',train.shape[0])
print('Counts of the Test Data : ',test.shape[0])
# Out:
# Counts of the Train Data :  1789
# Counts of the Test Data :  448

# %% [markdown]
# _**Creating the list of train dataset values in train_values and empty predictions list which will be appended after the prediction. Then fitting the model with ARIMA model with the best value got from auto_arima model in the train_values data and predicting with test data value and appending it to the predictions list and printing the comparison between predicted value and actual value**_

# %%
train_values = [x for x in train]
predictions = []
print('Printing Predicted vs Expected Values...')
print('\n')
for t in range(len(test)):
    model = ARIMA(train_values, order=(0,1,1))
    model_fit = model.fit()
    output = model_fit.forecast()
    pred_out = output[0]
    predictions.append(float(pred_out))
    test_in = test[t]
    train_values.append(test_in)
    print('predicted=%f, Actual=%f' % (pred_out, test_in))
# Out:
# Printing Predicted vs Expected Values...
#
#
# predicted=0.752641, Actual=0.759475
# predicted=0.761367, Actual=0.767060
# predicted=0.768637, Actual=0.757880
# predicted=0.754904, Actual=0.747075
# predicted=0.744907, Actual=0.734700
# predicted=0.731868, Actual=0.728480
# predicted=0.727540, Actual=0.714175
# predicted=0.710462, Actual=0.705880
# predicted=0.704607, Actual=0.714900
# predicted=0.717761, Actual=0.719660
# predicted=0.720188, Actual=0.715400
# predicted=0.714069, Actual=0.711920
# predicted=0.711323, Actual=0.716960
# predicted=0.718527, Actual=0.712280
# predicted=0.710545, Actual=0.703260
# predicted=0.701235, Actual=0.707200
# predicted=0.708857, Actual=0.696640
# predicted=0.693251, Actual=0.703760
# predicted=0.706666, Actual=0.704920
# predicted=0.704437, Actual=0.699480
# predicted=0.698108, Actual=0.701300
# predicted=0.702183, Actual=0.688660
# predicted=0.684922, Actual=0.681380
# predicted=0.680401, Actual=0.679100
# predicted=0.678740, Actual=0.685340
# predicted=0.687166, Actual=0.679580
# predicted=0.677483, Actual=0.672480
# predicted=0.671096, Actual=0.667460
# predicted=0.666454, Actual=0.674800
# predicted=0.677108, Actual=0.674860
# predicted=0.674239, Actual=0.669040
# predicted=0.667602, Actual=0.671200
# predicted=0.672194, Actual=0.667120
# predicted=0.665718, Actual=0.665280
# predicted=0.665159, Actual=0.678860
# predicted=0.682646, Actual=0.690600
# predicted=0.692800, Actual=0.698850
# predicted=0.700526, Actual=0.696767
# predicted=0.695725, Actual=0.695480
# predicted=0.695412, Actual=0.690240
# predicted=0.688807, Actual=0.704600
# predicted=0.708968, Actual=0.713120
# predicted=0.714268, Actual=0.722420
# predicted=0.724679, Actual=0.731520
# predicted=0.733417, Actual=0.734320
# predicted=0.734570, Actual=0.735960
# predicted=0.736345, Actual=0.735880
# predicted=0.735751, Actual=0.731760
# predicted=0.730653, Actual=0.732360
# predicted=0.732833, Actual=0.744560
# predicted=0.747814, Actual=0.741225
# predicted=0.739401, Actual=0.747275
# predicted=0.749454, Actual=0.736720
# predicted=0.733202, Actual=0.746480
# predicted=0.750135, Actual=0.753180
# predicted=0.754019, Actual=0.780425
# predicted=0.787718, Actual=0.791220
# predicted=0.792185, Actual=0.807300
# predicted=0.811485, Actual=0.813860
# predicted=0.814517, Actual=0.820875
# predicted=0.822637, Actual=0.831520
# predicted=0.833983, Actual=0.811160
# predicted=0.804853, Actual=0.812840
# predicted=0.815034, Actual=0.808980
# predicted=0.807314, Actual=0.792120
# predicted=0.787933, Actual=0.783400
# predicted=0.782150, Actual=0.776420
# predicted=0.774838, Actual=0.768640
# predicted=0.766928, Actual=0.757560
# predicted=0.754970, Actual=0.771260
# predicted=0.775752, Actual=0.779820
# predicted=0.780942, Actual=0.788360
# predicted=0.790410, Actual=0.780975
# predicted=0.778372, Actual=0.783560
# predicted=0.784990, Actual=0.768960
# predicted=0.764547, Actual=0.752660
# predicted=0.749381, Actual=0.735180
# predicted=0.731247, Actual=0.721660
# predicted=0.719000, Actual=0.716520
# predicted=0.715831, Actual=0.717820
# predicted=0.718372, Actual=0.720200
# predicted=0.720708, Actual=0.712420
# predicted=0.710118, Actual=0.725920
# predicted=0.730297, Actual=0.735820
# predicted=0.737351, Actual=0.746040
# predicted=0.748453, Actual=0.760860
# predicted=0.764311, Actual=0.754800
# predicted=0.752161, Actual=0.752560
# predicted=0.752671, Actual=0.763200
# predicted=0.766123, Actual=0.753167
# predicted=0.749580, Actual=0.762275
# predicted=0.765778, Actual=0.761940
# predicted=0.760882, Actual=0.744460
# predicted=0.739925, Actual=0.730980
# predicted=0.728506, Actual=0.730040
# predicted=0.730465, Actual=0.734540
# predicted=0.735668, Actual=0.738460
# predicted=0.739233, Actual=0.728140
# predicted=0.725069, Actual=0.719960
# predicted=0.718545, Actual=0.719720
# predicted=0.720046, Actual=0.714060
# predicted=0.712402, Actual=0.705640
# predicted=0.703766, Actual=0.708180
# predicted=0.709403, Actual=0.699240
# predicted=0.696427, Actual=0.691300
# predicted=0.689880, Actual=0.694575
# predicted=0.695875, Actual=0.680467
# predicted=0.676205, Actual=0.679825
# predicted=0.680824, Actual=0.701100
# predicted=0.706709, Actual=0.703600
# predicted=0.702742, Actual=0.708700
# predicted=0.710346, Actual=0.692000
# predicted=0.686941, Actual=0.687240
# predicted=0.687322, Actual=0.698440
# predicted=0.701506, Actual=0.700020
# predicted=0.699610, Actual=0.694260
# predicted=0.692785, Actual=0.695420
# predicted=0.696146, Actual=0.710060
# predicted=0.713898, Actual=0.702720
# predicted=0.699647, Actual=0.695600
# predicted=0.694487, Actual=0.703620
# predicted=0.706133, Actual=0.703520
# predicted=0.702802, Actual=0.694180
# predicted=0.691808, Actual=0.695500
# predicted=0.696515, Actual=0.698200
# predicted=0.698663, Actual=0.715360
# predicted=0.719954, Actual=0.728940
# predicted=0.731416, Actual=0.735340
# predicted=0.736423, Actual=0.737740
# predicted=0.738104, Actual=0.748960
# predicted=0.751957, Actual=0.728280
# predicted=0.721774, Actual=0.726300
# predicted=0.727538, Actual=0.715120
# predicted=0.711716, Actual=0.725420
# predicted=0.729164, Actual=0.730360
# predicted=0.730687, Actual=0.738360
# predicted=0.740459, Actual=0.747360
# predicted=0.749249, Actual=0.745720
# predicted=0.744754, Actual=0.747240
# predicted=0.747920, Actual=0.765740
# predicted=0.770619, Actual=0.765480
# predicted=0.764077, Actual=0.773200
# predicted=0.775691, Actual=0.777250
# predicted=0.777676, Actual=0.785380
# predicted=0.787486, Actual=0.780820
# predicted=0.779000, Actual=0.765820
# predicted=0.762216, Actual=0.761120
# predicted=0.760820, Actual=0.756840
# predicted=0.755751, Actual=0.761960
# predicted=0.763658, Actual=0.751340
# predicted=0.747977, Actual=0.749300
# predicted=0.749661, Actual=0.759220
# predicted=0.761830, Actual=0.763200
# predicted=0.763574, Actual=0.756300
# predicted=0.754313, Actual=0.751480
# predicted=0.750706, Actual=0.757350
# predicted=0.759165, Actual=0.762475
# predicted=0.763379, Actual=0.761340
# predicted=0.760783, Actual=0.757580
# predicted=0.756705, Actual=0.758980
# predicted=0.759602, Actual=0.771725
# predicted=0.775039, Actual=0.783900
# predicted=0.786325, Actual=0.791160
# predicted=0.792485, Actual=0.803980
# predicted=0.807132, Actual=0.799433
# predicted=0.797326, Actual=0.796680
# predicted=0.796503, Actual=0.792380
# predicted=0.791251, Actual=0.799720
# predicted=0.802038, Actual=0.801480
# predicted=0.801327, Actual=0.816580
# predicted=0.820755, Actual=0.817720
# predicted=0.816891, Actual=0.819760
# predicted=0.820544, Actual=0.814940
# predicted=0.813408, Actual=0.808860
# predicted=0.807616, Actual=0.811460
# predicted=0.812511, Actual=0.801440
# predicted=0.798415, Actual=0.796850
# predicted=0.796422, Actual=0.791400
# predicted=0.790027, Actual=0.774400
# predicted=0.770124, Actual=0.767020
# predicted=0.766171, Actual=0.775880
# predicted=0.778538, Actual=0.771540
# predicted=0.769627, Actual=0.773080
# predicted=0.774023, Actual=0.766860
# predicted=0.764903, Actual=0.770500
# predicted=0.772028, Actual=0.773700
# predicted=0.774157, Actual=0.784000
# predicted=0.786689, Actual=0.785560
# predicted=0.785252, Actual=0.777880
# predicted=0.775866, Actual=0.771740
# predicted=0.770612, Actual=0.767640
# predicted=0.766827, Actual=0.767340
# predicted=0.767480, Actual=0.757100
# predicted=0.754263, Actual=0.756300
# predicted=0.756856, Actual=0.761025
# predicted=0.762164, Actual=0.760300
# predicted=0.759791, Actual=0.750080
# predicted=0.747426, Actual=0.749300
# predicted=0.749812, Actual=0.737720
# predicted=0.734418, Actual=0.741920
# predicted=0.743965, Actual=0.746560
# predicted=0.747268, Actual=0.752380
# predicted=0.753775, Actual=0.763900
# predicted=0.766665, Actual=0.768040
# predicted=0.768416, Actual=0.768880
# predicted=0.769007, Actual=0.772600
# predicted=0.773582, Actual=0.778800
# predicted=0.780226, Actual=0.775775
# predicted=0.774559, Actual=0.764700
# predicted=0.762005, Actual=0.764320
# predicted=0.764952, Actual=0.768360
# predicted=0.769291, Actual=0.761460
# predicted=0.759321, Actual=0.764450
# predicted=0.765850, Actual=0.774460
# predicted=0.776812, Actual=0.775940
# predicted=0.775702, Actual=0.771650
# predicted=0.770543, Actual=0.762220
# predicted=0.759945, Actual=0.752520
# predicted=0.750489, Actual=0.752440
# predicted=0.752974, Actual=0.767240
# predicted=0.771144, Actual=0.771780
# predicted=0.771954, Actual=0.774020
# predicted=0.774586, Actual=0.763320
# predicted=0.760237, Actual=0.755880
# predicted=0.754687, Actual=0.754140
# predicted=0.753990, Actual=0.750720
# predicted=0.749824, Actual=0.753280
# predicted=0.754226, Actual=0.747380
# predicted=0.745506, Actual=0.752700
# predicted=0.754667, Actual=0.759620
# predicted=0.760975, Actual=0.753140
# predicted=0.750997, Actual=0.745200
# predicted=0.743614, Actual=0.740620
# predicted=0.739800, Actual=0.736700
# predicted=0.735851, Actual=0.737840
# predicted=0.738385, Actual=0.735980
# predicted=0.735322, Actual=0.726480
# predicted=0.724059, Actual=0.730980
# predicted=0.732873, Actual=0.743560
# predicted=0.746487, Actual=0.744260
# predicted=0.743651, Actual=0.740760
# predicted=0.739968, Actual=0.736880
# predicted=0.736034, Actual=0.734860
# predicted=0.734538, Actual=0.727120
# predicted=0.725088, Actual=0.729020
# predicted=0.730096, Actual=0.728833
# predicted=0.728488, Actual=0.729275
# predicted=0.729491, Actual=0.734160
# predicted=0.735438, Actual=0.734280
# predicted=0.733963, Actual=0.734900
# predicted=0.735157, Actual=0.735020
# predicted=0.734983, Actual=0.737720
# predicted=0.738469, Actual=0.732460
# predicted=0.730815, Actual=0.728220
# predicted=0.727510, Actual=0.728660
# predicted=0.728975, Actual=0.725080
# predicted=0.724014, Actual=0.719400
# predicted=0.718137, Actual=0.721380
# predicted=0.722268, Actual=0.726360
# predicted=0.727480, Actual=0.727220
# predicted=0.727149, Actual=0.723320
# predicted=0.722272, Actual=0.723575
# predicted=0.723932, Actual=0.723575
# predicted=0.723477, Actual=0.721960
# predicted=0.721545, Actual=0.721050
# predicted=0.720915, Actual=0.728960
# predicted=0.731163, Actual=0.731380
# predicted=0.731440, Actual=0.734350
# predicted=0.735147, Actual=0.734180
# predicted=0.733915, Actual=0.738020
# predicted=0.739144, Actual=0.736420
# predicted=0.735675, Actual=0.734740
# predicted=0.734484, Actual=0.732900
# predicted=0.732466, Actual=0.734720
# predicted=0.735337, Actual=0.737920
# predicted=0.738627, Actual=0.742340
# predicted=0.743356, Actual=0.745840
# predicted=0.746520, Actual=0.747280
# predicted=0.747488, Actual=0.747500
# predicted=0.747503, Actual=0.752060
# predicted=0.753308, Actual=0.758225
# predicted=0.759572, Actual=0.765480
# predicted=0.767099, Actual=0.773340
# predicted=0.775051, Actual=0.773980
# predicted=0.773686, Actual=0.782160
# predicted=0.784483, Actual=0.792700
# predicted=0.794954, Actual=0.790840
# predicted=0.789712, Actual=0.785520
# predicted=0.784370, Actual=0.787480
# predicted=0.788333, Actual=0.789040
# predicted=0.789234, Actual=0.801360
# predicted=0.804687, Actual=0.802540
# predicted=0.801952, Actual=0.800260
# predicted=0.799796, Actual=0.801320
# predicted=0.801738, Actual=0.807360
# predicted=0.808902, Actual=0.806780
# predicted=0.806198, Actual=0.808240
# predicted=0.808800, Actual=0.818967
# predicted=0.821755, Actual=0.824225
# predicted=0.824902, Actual=0.843380
# predicted=0.848454, Actual=0.855300
# predicted=0.857181, Actual=0.870340
# predicted=0.873966, Actual=0.883100
# predicted=0.885620, Actual=0.877380
# predicted=0.875108, Actual=0.881240
# predicted=0.882929, Actual=0.878360
# predicted=0.877102, Actual=0.885300
# predicted=0.887556, Actual=0.903620
# predicted=0.908049, Actual=0.938840
# predicted=0.947393, Actual=0.939280
# predicted=0.937041, Actual=0.915240
# predicted=0.909187, Actual=0.925750
# predicted=0.930316, Actual=0.931425
# predicted=0.931731, Actual=0.937160
# predicted=0.938660, Actual=0.927940
# predicted=0.924981, Actual=0.902080
# predicted=0.895737, Actual=0.888425
# predicted=0.886397, Actual=0.884020
# predicted=0.883359, Actual=0.897000
# predicted=0.900790, Actual=0.916200
# predicted=0.920492, Actual=0.898120
# predicted=0.891922, Actual=0.888800
# predicted=0.887936, Actual=0.885700
# predicted=0.885079, Actual=0.891380
# predicted=0.893129, Actual=0.899140
# predicted=0.900809, Actual=0.904280
# predicted=0.905244, Actual=0.913580
# predicted=0.915897, Actual=0.915040
# predicted=0.914802, Actual=0.906700
# predicted=0.904448, Actual=0.914860
# predicted=0.917749, Actual=0.901600
# predicted=0.897133, Actual=0.898220
# predicted=0.898521, Actual=0.880020
# predicted=0.874902, Actual=0.894950
# predicted=0.900457, Actual=0.892900
# predicted=0.890831, Actual=0.884540
# predicted=0.882813, Actual=0.893900
# predicted=0.896941, Actual=0.891800
# predicted=0.890392, Actual=0.887440
# predicted=0.886631, Actual=0.878040
# predicted=0.875684, Actual=0.889800
# predicted=0.893662, Actual=0.906340
# predicted=0.909816, Actual=0.918300
# predicted=0.920632, Actual=0.931940
# predicted=0.935053, Actual=0.936060
# predicted=0.936337, Actual=0.942140
# predicted=0.943738, Actual=0.935200
# predicted=0.932850, Actual=0.915480
# predicted=0.910690, Actual=0.916240
# predicted=0.917767, Actual=0.915075
# predicted=0.914334, Actual=0.917133
# predicted=0.917904, Actual=0.925920
# predicted=0.928128, Actual=0.920700
# predicted=0.918657, Actual=0.920600
# predicted=0.921134, Actual=0.920620
# predicted=0.920478, Actual=0.906700
# predicted=0.902909, Actual=0.889040
# predicted=0.885216, Actual=0.898880
# predicted=0.902637, Actual=0.908480
# predicted=0.910088, Actual=0.917580
# predicted=0.919645, Actual=0.903280
# predicted=0.898777, Actual=0.894500
# predicted=0.893323, Actual=0.892350
# predicted=0.892082, Actual=0.883300
# predicted=0.880880, Actual=0.878460
# predicted=0.877793, Actual=0.882480
# predicted=0.883772, Actual=0.884000
# predicted=0.884063, Actual=0.882640
# predicted=0.882248, Actual=0.872800
# predicted=0.870196, Actual=0.878380
# predicted=0.880632, Actual=0.887180
# predicted=0.888983, Actual=0.895760
# predicted=0.897628, Actual=0.893000
# predicted=0.891725, Actual=0.881240
# predicted=0.878348, Actual=0.890660
# predicted=0.894048, Actual=0.887300
# predicted=0.885447, Actual=0.902880
# predicted=0.907662, Actual=0.902180
# predicted=0.900680, Actual=0.902660
# predicted=0.903202, Actual=0.908120
# predicted=0.909467, Actual=0.905840
# predicted=0.904847, Actual=0.896540
# predicted=0.894264, Actual=0.897600
# predicted=0.898514, Actual=0.886780
# predicted=0.883568, Actual=0.885600
# predicted=0.886156, Actual=0.896075
# predicted=0.898790, Actual=0.891100
# predicted=0.888999, Actual=0.891240
# predicted=0.891852, Actual=0.893720
# predicted=0.894230, Actual=0.890820
# predicted=0.889888, Actual=0.894120
# predicted=0.895276, Actual=0.904860
# predicted=0.907480, Actual=0.913620
# predicted=0.915300, Actual=0.917360
# predicted=0.917924, Actual=0.903520
# predicted=0.899579, Actual=0.913160
# predicted=0.916860, Actual=0.936860
# predicted=0.942333, Actual=0.945060
# predicted=0.945807, Actual=0.941900
# predicted=0.940829, Actual=0.936860
# predicted=0.935772, Actual=0.948440
# predicted=0.951911, Actual=0.958640
# predicted=0.960485, Actual=0.954200
# predicted=0.952477, Actual=0.951600
# predicted=0.951360, Actual=0.945180
# predicted=0.943485, Actual=0.938440
# predicted=0.937056, Actual=0.932520
# predicted=0.931275, Actual=0.928520
# predicted=0.927764, Actual=0.935940
# predicted=0.938184, Actual=0.942780
# predicted=0.944042, Actual=0.945760
# predicted=0.946232, Actual=0.945500
# predicted=0.945299, Actual=0.943900
# predicted=0.943516, Actual=0.935900
# predicted=0.933808, Actual=0.926700
# predicted=0.924747, Actual=0.927140
# predicted=0.927798, Actual=0.938880
# predicted=0.941927, Actual=0.941850
# predicted=0.941829, Actual=0.933150
# predicted=0.930764, Actual=0.918800
# predicted=0.915506, Actual=0.914425
# predicted=0.914127, Actual=0.917740
# predicted=0.918735, Actual=0.900400
# predicted=0.895355, Actual=0.891920
# predicted=0.890975, Actual=0.890350
# predicted=0.890178, Actual=0.889880
# predicted=0.889798, Actual=0.892240
# predicted=0.892913, Actual=0.896180
# predicted=0.897080, Actual=0.882160
# predicted=0.878053, Actual=0.879620
# predicted=0.880051, Actual=0.876020
# predicted=0.874911, Actual=0.864200
# predicted=0.861252, Actual=0.856980
# predicted=0.855804, Actual=0.846240
# predicted=0.843604, Actual=0.850020
# predicted=0.851786, Actual=0.851780
# predicted=0.851778, Actual=0.846460
# predicted=0.844995, Actual=0.838525
# predicted=0.836742, Actual=0.836180
# predicted=0.836025, Actual=0.837640
# predicted=0.838085, Actual=0.835860
# predicted=0.835247, Actual=0.847900
# predicted=0.851385, Actual=0.851820
# predicted=0.851940, Actual=0.846280
# predicted=0.844721, Actual=0.847980
# predicted=0.848877, Actual=0.853260
# predicted=0.854467, Actual=0.859360
# predicted=0.860708, Actual=0.862600

# %% [markdown]
# _**Evaluating the model with the following metrics such asPercentage of R2 Score, Mean Squared Error, Root Mean Squared Error, Mean Absolute Error and Mean Absolute Percentage Error for the predicted value and test data**_

# %%
print('Evaluation Results for Test Data : \n')
print(' Percenatge of R2 Score : {0:.2f} %'.format(100*(r2_score(test,predictions))),'\n')
print(' Mean Squared Error : %.6f'%(mean_squared_error(test,predictions)),'\n')
print(' Root Mean Squared Error : ',sqrt(mean_squared_error(test,predictions)),'\n')
print(' Mean Absolute Error : ',mean_absolute_error(test,predictions),'\n')
print(' Mean Absolute Percentage Error : {0:.2f} %'.format(100*mean_absolute_percentage_error(test,predictions)),'\n')
# Out:
# Evaluation Results for Test Data :
#
#  Percenatge of R2 Score : 98.96 %
#
#  Mean Squared Error : 0.000067
#
#  Root Mean Squared Error :  0.008174056061227111
#
#  Mean Absolute Error :  0.006431044705719191
#
#  Mean Absolute Percentage Error : 0.81 %

# %% [markdown]
# _**Making the predicted value as Series and index as same as Test data index since the prediction is based on Test Data**_

# %%
predictions_df = pd.Series(predictions, index = test.index)

# %% [markdown]
# _**Plotting the graph with predicted data and the resampled weekly data and saving it as PNG file**_

# %%
fig, ax = plt.subplots()
ax.set(title='Foreign Exchange Rate Prediction- Euro to USD', xlabel='Date', ylabel='Foreign Exchange Rate')
ax.plot(df_week, 'o', label='Actual')
ax.plot(predictions_df, 'r', label='Forecast')
legend = ax.legend(loc='upper right')
legend.get_frame().set_facecolor('w')
plt.savefig('Foreign Exchange Rate Prediction- Euro to USD.png')

# %% [markdown]
# _**Creating the pickle file with the best model that gives high evaluation score for the test data**_

# %%
pickle.dump(model_fit,open('Best Model.pkl','wb'))
